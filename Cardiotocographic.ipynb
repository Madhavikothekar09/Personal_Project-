# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("../Data_Sets/Cardiotocographic.csv")

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
##DATA CLEANING AND PREPARATION

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df[df.isnull().any(axis=1)]
# Out:
#       LB        AC        FM        UC        DL  DS  DP       ASTV      MSTV  \
# 50   NaN       NaN  0.000000  0.008086  0.000000 NaN NaN  29.000000  1.300000
# 116  NaN  0.038567  0.000000  0.006993  0.002331 NaN NaN  26.000000  4.300000
# 126  NaN       NaN  0.000000  0.004380  0.000000 NaN NaN  69.000000  0.300000
# 201  NaN       NaN  0.016393  0.000000  0.000000 NaN NaN  56.000000  0.500000
# 566  NaN       NaN  0.000000  0.004115  0.005487 NaN NaN  43.000000  2.500000
# 574  NaN       NaN  0.000000  0.002611  0.002611 NaN NaN  34.000000  4.900000
# 603  NaN       NaN  0.006519  0.001304  0.001304 NaN NaN  73.000000  0.700000
# 935  NaN       NaN  0.000000  0.005495  0.001374 NaN NaN  30.000000  1.251793
# 936  NaN       NaN  0.000000  0.007802  0.000000 NaN NaN  33.000000  1.000000
# 1013 NaN       NaN  0.000000  0.003861  0.000000 NaN NaN  34.000000  1.000000
# 1205 NaN       NaN -0.000129  0.006424  0.000000 NaN NaN  63.000000  0.500000
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
##Statistical Summary:

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean    133.343598     0.003202     0.009963     0.004388     0.001892
# std      11.270154     0.004324     0.067870     0.003350     0.003348
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001838     0.000000
# 50%     133.000000     0.001631     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002554     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean      0.000003     0.000175    46.996929     1.361006    10.353647
# std       0.000142     0.000840    18.847737     1.173164    21.282102
# ...

# %%
Q1=np.percentile(df,25)
Q3 = np.percentile(df, 75)
IQR = Q3 - Q1

print("Q1 (25th percentile):", Q1)
print("Q3 (75th percentile):", Q3)
print("Interquartile Range (IQR):", IQR)

C1=10.6+(1.5*10.6)
C2=0.0-(1.5*10.6)

print("C1:",C1)
print("C2:", C2)
# Out:
# Q1 (25th percentile): 0.0
# Q3 (75th percentile): 10.6
# Interquartile Range (IQR): 10.6
# C1: 26.5
# C2: -15.899999999999999

# %%
q1 = np.percentile(df.ASTV, 25)
q3 = np.percentile(df.ASTV, 75)
iqr = q3 - q1
c2=q3-(1.5*iqr)
c1=q1+(1.5*iqr)
t=df[(df.ASTV < C2)|(df.ASTV > C1)]
t
# Out:
#          LB        AC        FM        UC        DL   DS        DP  ASTV  \
# 0     120.0  0.000000  0.000000  0.000000  0.000000  0.0  0.000000  73.0
# 6     134.0  0.001403  0.000000  0.012623  0.008415  0.0  0.002805  29.0
# 7     122.0  0.000000  0.000000  0.000000  0.000000  0.0  0.000000  83.0
# 8     122.0  0.038567  0.000000  0.001517  0.000000  0.0  0.000000  84.0
# 9     122.0  0.000000  0.000000  0.002967  0.000000  0.0  0.000000  86.0
# ...     ...       ...       ...       ...       ...  ...       ...   ...
# 2121  140.0  0.000000  0.961268  0.007426  0.000000  0.0  0.000000  79.0
# 2122  140.0  0.000775  0.000000  0.006979  0.000000  0.0  0.000000  78.0
# 2123  140.0  0.000980  0.000000  0.006863  0.000000  0.0  0.000000  79.0
# 2124  140.0  0.000679  0.000000  0.006110  0.000000  0.0  0.000000  78.0
# 2125  142.0  0.001616 -0.000188  0.008078  0.000000  0.0  0.000000  74.0
#
#       MSTV       ALTV  MLTV       Width  Tendency       NSP
# ...

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
##Data Visualization:

# %%
fig=plt.figure(figsize=(18,9))
plt.subplots_adjust(hspace=0.8)


fig.add_subplot(331)
sb.histplot(df.LB,kde=True,color='indianred')

fig.add_subplot(332)
sb.histplot(df.AC,kde=True,color='indianred')

fig.add_subplot(333)
sb.histplot(df.FM,kde=True,color='indianred')

fig.add_subplot(334)
sb.histplot(df.UC,kde=True,color='indianred')

fig.add_subplot(335)
sb.histplot(df.DL,kde=True,color='indianred')

fig.add_subplot(336)
sb.histplot(df.DS,kde=True,color='indianred')

plt.show()

# %%
fig=plt.figure(figsize=(18,9))
plt.subplots_adjust(hspace=0.5)

fig.add_subplot(331)
sb.histplot(df.DP,kde=True)

fig.add_subplot(332)
sb.histplot(df.ASTV,kde=True)

fig.add_subplot(333)
sb.histplot(df.MLTV,kde=True)

fig.add_subplot(334)
sb.histplot(df.Width,kde=True)


fig.add_subplot(335)
sb.histplot(df.Tendency,kde=True)

fig.add_subplot(336)
sb.histplot(df.NSP,kde=True)

plt.show()

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
fig=plt.figure(figsize=(15,7))
plt.subplots_adjust(hspace=0.5)

fig.add_subplot(231)
sb.boxplot(df.LB)
plt.title('Boxplot of LB')

fig.add_subplot(232)
sb.boxplot(df.AC)
plt.title('Boxplot of AC')

fig.add_subplot(233)
sb.boxplot(df.FM)
plt.title('Boxplot of FM')


fig.add_subplot(234)
sb.boxplot(df.UC)
plt.title('Boxplot of UC')


fig.add_subplot(235)
sb.boxplot(df.DL)
plt.title('Boxplot of DL')

fig.add_subplot(236)
sb.boxplot(df.DS)
plt.title('Boxplot of DS')


plt.show()

# %%
fig=plt.figure(figsize=(15,7))
plt.subplots_adjust(hspace=0.5)

fig.add_subplot(231)
sb.boxplot(df.DP)
plt.title('Boxplot of DP')

fig.add_subplot(232)
sb.boxplot(df.ASTV)
plt.title('Boxplot of ASTV')

fig.add_subplot(233)
sb.boxplot(df.MSTV)
plt.title('Boxplot of MSTV')

fig.add_subplot(234)
sb.boxplot(df.ALTV)
plt.title('Boxplot of ALTV')

fig.add_subplot(235)
sb.boxplot(df.MLTV)
plt.title('Boxplot of MLTV')

fig.add_subplot(236)
sb.boxplot(df.Width)
plt.title('Boxplot of Width')

plt.show()

# %%
fig=plt.figure(figsize=(10,5))

x1=fig.add_subplot(221)
sb.boxplot(df.Tendency)
plt.title('Boxplot of Tendency')

x2=fig.add_subplot(222)
sb.boxplot(df.NSP)
plt.title('Boxplot of NSP')

plt.show()

# %%
corr=df[['LB', 'AC','FM','UC','DL','DS','DP','ASTV','MSTV','ALTV','MLTV','Width','Tendency','NSP']].corr()
plt.figure(figsize=(10,8))
sb.heatmap(corr,annot=True,cmap="Blues",fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
corr=df.corr(numeric_only=True)
corr
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.063830  0.018777 -0.166570 -0.126959 -0.005438
# AC       -0.063830  1.000000  0.010152  0.070135 -0.095491 -0.033623
# FM        0.018777  0.010152  1.000000 -0.052979  0.009830  0.029901
# UC       -0.166570  0.070135 -0.052979  1.000000  0.191864 -0.006937
# DL       -0.126959 -0.095491  0.009830  0.191864  1.000000  0.058625
# DS       -0.005438 -0.033623  0.029901 -0.006937  0.058625  1.000000
# DP       -0.047724 -0.084590  0.121284  0.070658  0.145425  0.004285
# ASTV      0.242625 -0.230487 -0.032783 -0.181133 -0.070792  0.008452
# MSTV     -0.170473  0.126752  0.017481  0.190011  0.410155  0.016163
# ALTV      0.210728 -0.273890 -0.012276 -0.227817 -0.186571 -0.004398
# MLTV     -0.003457 -0.106529 -0.006237 -0.049460 -0.165750  0.034349
# Width    -0.118425  0.238436  0.097213  0.107397  0.410031  0.040832
# Tendency  0.236864  0.032481 -0.018339 -0.066610 -0.023569 -0.015398
# ...

# %%
sb.pairplot(corr)
plt.show()
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.violinplot(df.LB)
# Out:
# <Axes: >

# %%
sb.violinplot(df.AC)
# Out:
# <Axes: >

# %%
sb.violinplot(df.FM)
# Out:
# <Axes: >

# %%
sb.violinplot(df.UC)
# Out:
# <Axes: >

# %%
sb.violinplot(df.DL)
# Out:
# <Axes: >

# %%
sb.violinplot(df.DS)
# Out:
# <Axes: >

# %%
sb.violinplot(df.DP)
# Out:
# <Axes: >

# %%
sb.violinplot(df.ASTV)
# Out:
# <Axes: >

# %%
sb.violinplot(df.MSTV)
# Out:
# <Axes: >

# %%
sb.violinplot(df.ASTV)
# Out:
# <Axes: >

# %%
sb.violinplot(df.MSTV)
# Out:
# <Axes: >

# %%
sb.violinplot(df.ALTV)
# Out:
# <Axes: >

# %%
sb.violinplot(df.MLTV)
# Out:
# <Axes: >

# %%
sb.violinplot(df.Width)
# Out:
# <Axes: >

# %%
sb.violinplot(df.Tendency)
# Out:
# <Axes: >

# %%
sb.violinplot(df.NSP)
# Out:
# <Axes: >
