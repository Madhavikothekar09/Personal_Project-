# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("../Data_Sets/adult_with_headers.csv")

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
df.age.value_counts()
# Out:
# age
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: count, Length: 73, dtype: int64

# %%
df.workclass.value_counts()
# Out:
# workclass
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: count, dtype: int64

# %%
df.fnlwgt.value_counts()
# Out:
# fnlwgt
# 164190    13
# 203488    13
# 123011    13
# 148995    12
# 121124    12
#           ..
# 232784     1
# 325573     1
# 140176     1
# 318264     1
# 257302     1
# Name: count, Length: 21648, dtype: int64

# %%
df.education.value_counts()
# Out:
# education
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: count, dtype: int64

# %%
df.education_num.value_counts()
# Out:
# education_num
# 9     10501
# 10     7291
# 13     5355
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: count, dtype: int64

# %%
df.marital_status.value_counts()
# Out:
# marital_status
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: count, dtype: int64

# %%
df.occupation.value_counts()
# Out:
# occupation
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: count, dtype: int64

# %%
df.relationship.value_counts()
# Out:
# relationship
#  Husband           13193
#  Not-in-family      8305
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: count, dtype: int64

# %%
df.race.value_counts()
# Out:
# race
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: count, dtype: int64

# %%
df.sex.value_counts()
# Out:
# sex
#  Male      21790
#  Female    10771
# Name: count, dtype: int64

# %%
df.capital_gain.value_counts()
# Out:
# capital_gain
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: count, Length: 119, dtype: int64

# %%
df.capital_loss.value_counts()
# Out:
# capital_loss
# 0       31042
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 2080        1
# 1539        1
# 1844        1
# 2489        1
# 1411        1
# Name: count, Length: 92, dtype: int64

# %%
df.hours_per_week.value_counts()
# Out:
# hours_per_week
# 40    15217
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 82        1
# 92        1
# 87        1
# 74        1
# 94        1
# Name: count, Length: 94, dtype: int64

# %%
df.native_country.value_counts()
# Out:
# native_country
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
df.occupation.value_counts()
# Out:
# occupation
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: count, dtype: int64

# %%
quee_mark=df[df.occupation==' ?']
quee_mark
# Out:
#        age workclass  fnlwgt      education  education_num  \
# 27      54         ?  180211   Some-college             10
# 61      32         ?  293936        7th-8th              4
# 69      25         ?  200681   Some-college             10
# 77      67         ?  212759           10th              6
# 106     17         ?  304873           10th              6
# ...    ...       ...     ...            ...            ...
# 32530   35         ?  320084      Bachelors             13
# 32531   30         ?   33811      Bachelors             13
# 32539   71         ?  287372      Doctorate             16
# 32541   41         ?  202822        HS-grad              9
# 32542   72         ?  129912        HS-grad              9
#
#                marital_status occupation    relationship                 race  \
# 27         Married-civ-spouse          ?         Husband   Asian-Pac-Islander
# 61      Married-spouse-absent          ?   Not-in-family                White
# ...

# %%
que_mark=df[df.workclass==' ?']
que_mark
# Out:
#        age workclass  fnlwgt      education  education_num  \
# 27      54         ?  180211   Some-college             10
# 61      32         ?  293936        7th-8th              4
# 69      25         ?  200681   Some-college             10
# 77      67         ?  212759           10th              6
# 106     17         ?  304873           10th              6
# ...    ...       ...     ...            ...            ...
# 32530   35         ?  320084      Bachelors             13
# 32531   30         ?   33811      Bachelors             13
# 32539   71         ?  287372      Doctorate             16
# 32541   41         ?  202822        HS-grad              9
# 32542   72         ?  129912        HS-grad              9
#
#                marital_status occupation    relationship                 race  \
# 27         Married-civ-spouse          ?         Husband   Asian-Pac-Islander
# 61      Married-spouse-absent          ?   Not-in-family                White
# ...

# %%
df.workclass.value_counts()
# Out:
# workclass
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: count, dtype: int64

# %%
quee_mark[quee_mark.workclass==" Never-worked"]
# Out:
#        age      workclass  fnlwgt      education  education_num  \
# 5361    18   Never-worked  206359           10th              6
# 10845   23   Never-worked  188535        7th-8th              4
# 14772   17   Never-worked  237272           10th              6
# 20337   18   Never-worked  157131           11th              7
# 23232   20   Never-worked  462294   Some-college             10
# 32304   30   Never-worked  176673        HS-grad              9
# 32314   18   Never-worked  153663   Some-college             10
#
#             marital_status occupation    relationship    race      sex  \
# 5361         Never-married          ?       Own-child   White     Male
# 10845             Divorced          ?   Not-in-family   White     Male
# 14772        Never-married          ?       Own-child   White     Male
# 20337        Never-married          ?       Own-child   White   Female
# 23232        Never-married          ?       Own-child   Black     Male
# ...

# %%
##Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
label= LabelEncoder()

# %%
df1=df.copy()

# %%
df1['workclass']=label.fit_transform(df1['workclass'])
df1['education']=label.fit_transform(df1['education'])
df1['marital_status']=label.fit_transform(df1['marital_status'])
df1['occupation']=label.fit_transform(df1['occupation'])
df1['relationship']=label.fit_transform(df1['relationship'])
df1['race']=label.fit_transform(df1['race'])
df1['sex']=label.fit_transform(df1['sex'])
df1['native_country']=label.fit_transform(df1['native_country'])
df1
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# ...

# %%
##Isolation Forest

# %%
from sklearn.ensemble import IsolationForest

# %%
features = ['workclass','education','marital_status','occupation','relationship','race','sex','native_country']

# %%
iso_forest=IsolationForest(contamination=0.01,random_state=42)

# %%
outlaiers=iso_forest.fit_predict(df1[features])

# %%
outlaiers
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
df1['outlaiers'] = outlaiers

# %%
clean_data = df1[df1['outlaiers'] != -1]
clean_data
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# ...

# %%
df1.outlaiers.value_counts()
# Out:
# outlaiers
#  1    32235
# -1      326
# Name: count, dtype: int64

# %%
X = clean_data.drop(columns=['income', 'outlaiers'])
X
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# ...

# %%
y = clean_data['income']
y
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 32556     <=50K
# 32557      >50K
# 32558     <=50K
# 32559     <=50K
# 32560      >50K
# Name: income, Length: 32235, dtype: object

# %%
label_encoder = LabelEncoder()
label_encoder
y_encoded = label_encoder.fit_transform(y)
y_encoded
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)
X_train, X_test, y_train, y_test
# Out:
# (       age  workclass  fnlwgt  education  education_num  marital_status  \
#  26874   40          4  126701          6              5               4
#  16248   52          4  160703         11              9               2
#  20641   49          5   38819          9             13               2
#  20646   19          0  117201         15             10               4
#  21263   60          4  116230          5              4               2
#  ...    ...        ...     ...        ...            ...             ...
#  30099   57          4   49893         12             14               2
#  5447    20          4   89991         15             10               4
#  867     17          4  368700          1              7               4
#  15945   28          4  346406         11              9               2
#  23895   28          4  132191         11              9               2
#
#         occupation  relationship  race  sex  capital_gain  capital_loss  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(max_iter=1000, random_state=42)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.7874980611136962
