# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("../Data_Sets/sales_data_with_discounts (1).csv")

# %%
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'],format="%d-%m-%Y")

# %%
df
# Out:
#           Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0   2021-04-01  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1   2021-04-01  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2   2021-04-01  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3   2021-04-01  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4   2021-04-01  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..         ...       ...  ...  ...     ...        ...    ...         ...
# 445 2021-04-15  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446 2021-04-15  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447 2021-04-15  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448 2021-04-15  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449 2021-04-15  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.dtypes
# Out:
# Date                 datetime64[ns]
# Day                          object
# SKU                          object
# City                         object
# Volume                        int64
# BU                           object
# Brand                        object
# Model                        object
# Avg Price                     int64
# Total Sales Value             int64
# Discount Rate (%)           float64
# Discount Amount             float64
# Net Sales Value             float64
# dtype: object

# %%
df.columns = df.columns.str.replace(' ','_',regex=True)

# %%
df
# Out:
#           Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0   2021-04-01  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1   2021-04-01  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2   2021-04-01  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3   2021-04-01  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4   2021-04-01  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..         ...       ...  ...  ...     ...        ...    ...         ...
# 445 2021-04-15  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446 2021-04-15  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447 2021-04-15  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448 2021-04-15  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449 2021-04-15  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg_Price  Total_Sales_Value  Discount_Rate_(%)  Discount_Amount  \
# ...

# %%
df["Discount_Rate_(%)"]=round(df["Discount_Rate_(%)"],2)

# %%
df
# Out:
#           Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0   2021-04-01  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1   2021-04-01  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2   2021-04-01  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3   2021-04-01  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4   2021-04-01  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..         ...       ...  ...  ...     ...        ...    ...         ...
# 445 2021-04-15  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446 2021-04-15  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447 2021-04-15  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448 2021-04-15  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449 2021-04-15  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg_Price  Total_Sales_Value  Discount_Rate_(%)  Discount_Amount  \
# ...

# %%
df.describe()
# Out:
#                       Date      Volume     Avg_Price  Total_Sales_Value  \
# count                  450  450.000000    450.000000         450.000000
# mean   2021-04-08 00:00:00    5.066667  10453.433333       33812.835556
# min    2021-04-01 00:00:00    1.000000    290.000000         400.000000
# 25%    2021-04-04 00:00:00    3.000000    465.000000        2700.000000
# 50%    2021-04-08 00:00:00    4.000000   1450.000000        5700.000000
# 75%    2021-04-12 00:00:00    6.000000  10100.000000       53200.000000
# max    2021-04-15 00:00:00   31.000000  60100.000000      196400.000000
# std                    NaN    4.231602  18079.904840       50535.074173
#
#        Discount_Rate_(%)  Discount_Amount  Net_Sales_Value
# count         450.000000       450.000000       450.000000
# mean           15.155311      3346.499424     30466.336131
# min             5.010000        69.177942       326.974801
# 25%            13.962500       460.459304      2202.208645
# ...

# %%
round(df.describe(),2)
# Out:
#                       Date  Volume  Avg_Price  Total_Sales_Value  \
# count                  450  450.00     450.00             450.00
# mean   2021-04-08 00:00:00    5.07   10453.43           33812.84
# min    2021-04-01 00:00:00    1.00     290.00             400.00
# 25%    2021-04-04 00:00:00    3.00     465.00            2700.00
# 50%    2021-04-08 00:00:00    4.00    1450.00            5700.00
# 75%    2021-04-12 00:00:00    6.00   10100.00           53200.00
# max    2021-04-15 00:00:00   31.00   60100.00          196400.00
# std                    NaN    4.23   18079.90           50535.07
#
#        Discount_Rate_(%)  Discount_Amount  Net_Sales_Value
# count             450.00           450.00           450.00
# mean               15.16          3346.50         30466.34
# min                 5.01            69.18           326.97
# 25%                13.96           460.46          2202.21
# 50%                16.58           988.93          4677.79
# ...

# %%
#●Histograms:
#Plot histograms for each numerical column.

# %%
sb.histplot(df.Volume)
plt.show()

# %%
sb.histplot(df.Avg_Price)
plt.show()

# %%
sb.histplot(df.Total_Sales_Value)
plt.show()

# %%
df
# Out:
#           Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0   2021-04-01  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1   2021-04-01  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2   2021-04-01  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3   2021-04-01  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4   2021-04-01  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..         ...       ...  ...  ...     ...        ...    ...         ...
# 445 2021-04-15  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446 2021-04-15  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447 2021-04-15  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448 2021-04-15  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449 2021-04-15  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg_Price  Total_Sales_Value  Discount_Rate_(%)  Discount_Amount  \
# ...

# %%
df.columns = df.columns.str.replace('Discount_Rate_(%)','Discount_Rate_Percentage')

# %%
df
# Out:
#           Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0   2021-04-01  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1   2021-04-01  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2   2021-04-01  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3   2021-04-01  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4   2021-04-01  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..         ...       ...  ...  ...     ...        ...    ...         ...
# 445 2021-04-15  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446 2021-04-15  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447 2021-04-15  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448 2021-04-15  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449 2021-04-15  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg_Price  Total_Sales_Value  Discount_Rate_Percentage  Discount_Amount  \
# ...

# %%
fig=plt.figure(figsize=(16,8))

fig.add_subplot(231)
sb.histplot(df.Volume,kde=True)

fig.add_subplot(232)
sb.histplot(df.Avg_Price,kde=True)

fig.add_subplot(233)
sb.histplot(df.Total_Sales_Value,kde=True)

fig.add_subplot(234)
sb.histplot(df.Discount_Rate_Percentage,kde=True)


fig.add_subplot(235)
sb.histplot(df.Discount_Amount,kde=True)

fig.add_subplot(236)
sb.histplot(df.Net_Sales_Value,kde=True)
# Out:
# <Axes: xlabel='Net_Sales_Value', ylabel='Count'>

# %%
##Analyze the distribution (e.g., skewness, presence of outliers) and provide inferences.

# %%
sb.kdeplot(df.Volume)##SKEWNESS
plt.show()

# %% [markdown]
# q1=np.percentile(df.Volume,25)
# q3=np.percentile(df.Volume,75)
# iqr=q3-q1
# c2=q1-(1.5 * iqr)
# c1=q3+(1.5 * iqr
# t= df.(df.Volume<c2)|(df.Volume>c1)]
# t

# %%
q1=np.percentile(df.Volume,25) 
q3=np.percentile(df.Volume,75) 
iqr=q3-q1 
c2=q1-(1.5 * iqr) 
c1=q3+(1.5 * iqr)
t= df[(df.Volume<c2)|(df.Volume>c1)] 
t
# Out:
#           Date        Day  SKU City  Volume         BU   Brand  \
# 0   2021-04-01   Thursday  M01    C      15    Mobiles   RealU
# 10  2021-04-01   Thursday  F01    C      13       FMCG  Babaji
# 30  2021-04-02     Friday  M01    C      11    Mobiles   RealU
# 40  2021-04-02     Friday  F01    C      29       FMCG  Babaji
# 50  2021-04-02     Friday  L01    C      13  Lifestyle   Jeera
# 70  2021-04-03   Saturday  F01    C      24       FMCG  Babaji
# 71  2021-04-03   Saturday  F02    C      14       FMCG   Vedic
# 80  2021-04-03   Saturday  L01    C      12  Lifestyle   Jeera
# 100 2021-04-04     Sunday  F01    C      25       FMCG  Babaji
# 101 2021-04-04     Sunday  F02    C      15       FMCG   Vedic
# 102 2021-04-04     Sunday  F03    C      11       FMCG   Vedic
# 130 2021-04-05     Monday  F01    C      15       FMCG  Babaji
# 140 2021-04-05     Monday  L01    C      14  Lifestyle   Jeera
# 161 2021-04-06    Tuesday  F02    C      12       FMCG   Vedic
# ...

# %%
df
# Out:
#           Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0   2021-04-01  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1   2021-04-01  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2   2021-04-01  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3   2021-04-01  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4   2021-04-01  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..         ...       ...  ...  ...     ...        ...    ...         ...
# 445 2021-04-15  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446 2021-04-15  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447 2021-04-15  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448 2021-04-15  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449 2021-04-15  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg_Price  Total_Sales_Value  Discount_Rate_Percentage  Discount_Amount  \
# ...

# %%
##●Boxplots:

# %%
fig=plt.figure(figsize=(15,8))


fig.add_subplot(231)
sb.boxplot(df.Volume)
plt.title('Boxplot of Volume')

fig.add_subplot(232)
sb.boxplot(df.Avg_Price)
plt.title('Boxplot of Avg_Price')


fig.add_subplot(233)
sb.boxplot(df.Total_Sales_Value)
plt.title('Boxplot of Total_Sales_Value')


fig.add_subplot(234)
sb.boxplot(df.Discount_Rate_Percentage)
plt.title('Boxplot of Discount_Rate_Percentage')


fig.add_subplot(235)
sb.boxplot(df.Discount_Amount)
plt.title('Boxplot of .Discount_Amount')


fig.add_subplot(236)
sb.boxplot(df.Net_Sales_Value)
plt.title('Boxplot of Net_Sales_Value')
# Out:
# Text(0.5, 1.0, 'Boxplot of Net_Sales_Value')

# %%
##●Bar Chart Analysis for Categorical Column:

# %%
df
# Out:
#           Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0   2021-04-01  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1   2021-04-01  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2   2021-04-01  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3   2021-04-01  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4   2021-04-01  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..         ...       ...  ...  ...     ...        ...    ...         ...
# 445 2021-04-15  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446 2021-04-15  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447 2021-04-15  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448 2021-04-15  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449 2021-04-15  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg_Price  Total_Sales_Value  Discount_Rate_Percentage  Discount_Amount  \
# ...

# %%
fig=plt.figure(figsize=(16,8))


fig.add_subplot(121)
sb.barplot(x=df.Brand,y=df.Volume)
plt.title('Barplot of Volume')


fig.add_subplot(122)
sb.barplot(x=df.Brand,y=df.Avg_Price)
plt.title('Barplot of Avg_Price')
# Out:
# Text(0.5, 1.0, 'Barplot of Avg_Price')

# %%
fig=plt.figure(figsize=(16,8))

fig.add_subplot(121)
sb.barplot(x=df.Brand,y=df.Total_Sales_Value)
plt.title('Barplot of Total_Sales_Value')


fig.add_subplot(122)
sb.barplot(x=df.Brand,y=df.Discount_Rate_Percentage)
plt.title('Barplot of Discount_Rate_Percentage')
# Out:
# Text(0.5, 1.0, 'Barplot of Discount_Rate_Percentage')

# %%
fig=plt.figure(figsize=(15,8))


fig.add_subplot(121)
sb.barplot(x=df.Brand,y=df.Discount_Amount)
plt.title('Barplot of Discount_Amount')


fig.add_subplot(122)
sb.barplot(x=df.Brand,y=df.Net_Sales_Value)
plt.title('Barplot of Net_Sales_Value')
# Out:
# Text(0.5, 1.0, 'Barplot of Net_Sales_Value')

# %%
)
# Out:
#   Cell In[33], line 1
#     )
#     ^
# SyntaxError: unmatched ')'
